# %%
import os
os.environ["OPENROUTER_API_KEY"]="your api key"
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# !pip install -U langchain-core langchain-community langchain-openrouter requests ddgs

# %%
from langchain_openrouter import ChatOpenRouter
from langchain_core.tools import tool
import requests

# %% [markdown]
# # Built-in-tool

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_run = DuckDuckGoSearchRun()

# result = search_run.invoke("heartstopper forever")
# Out:
# /tmp/ipykernel_32679/1030651897.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun

# %% [markdown]
# # custom tool

# %%
@tool
def get_current_weather(city: str)->str:
  """
  This function fetches the current weather data for a given city
  """
  url=f"https://api.open-meteo.com/v1/forecast?latitude=28.61&longitude=77.20&current_weather=true"

  response = requests.get(url)
  return response.json()

# %%
# result

# %%
# we will create a llm
LLM = ChatOpenRouter(model = "cohere/north-mini-code:free")
# LLM.invoke("hi")

# %% [markdown]
# # now we have an LLM and a Tool now we can create a Agent out of it

# %%
# !pip install langchainhub

# %% [markdown]
# # Out Agent will be a ReAct agent that is Reasoning + Action

# %%
from langgraph.prebuilt import create_react_agent
import langchainhub as hub
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# step 2: create a ReAct agent manually(ReAct is a design pattern)
Agent = create_react_agent(
    model = LLM,
    tools = [search_run, get_current_weather]
)
#  this helps in planning and decision making
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# step 3: Wrap it with AgentExecutor
# agent_executor = AgentExecutor(
#     agent = Agent,
#     tools = [search_run],
#     verbose = True
# )
# executor helps in executing those plans tools and decisions made by the agent
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# step 4: lets invoke it
response = Agent.invoke(
    {
        "messages": [("user", "find the capitol of india, and its weather conditions")]
    }
)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
print(response['messages'][-1].content)
# Out:
# Based on my search, I can provide you with the information you requested:
#
# **Capital of India:** New Delhi is the capital of India. It's jointly administered by the Central Government of India and the local Government of Delhi, and serves as the capital of the National Capital Territory (NCT) of Delhi. New Delhi became the capital in 1912 when King George V ordered the capital to be moved from Kolkata to Delhi.
#
# **Current Weather Conditions in New Delhi:**
# - **Temperature:** 35.9°C
# - **Weather:** Clear conditions (weather code 0)
# - **Wind Speed:** 5.4 km/h
# - **Wind Direction:** 274° (west direction)
# - **Elevation:** 221 meters above sea level
#
# The weather appears to be quite warm and clear in New Delhi at the moment, with light winds coming from the west.
# ...
