# %%
# !pip install langchain langchain-core langchain-community pydantic -U ddgs

# %% [markdown]
# #Built-in Tool - DuckDuckGO Search

# %%
# for real time websearch
from langchain_community.tools import DuckDuckGoSearchRun
# object of tool
search_tool = DuckDuckGoSearchRun()
# tools are also runnables
result = search_tool.invoke('heartstopper forever')
print(result)
# Out:
# Heartstopper Forever is an upcoming feature-length romantic comedy film that serves as the series finale for the Netflix adaptation of Alice Oseman's Heartstopper graphic novels. Directed by Wash Westmoreland and written by Oseman, who also serves a… Heartstopper Forever Is About To Change EVERYTHINGHeartstopper is officially back… and this time, it’s bigger than ever.The first look at Heartstopper: Forev... Heartstopper Forever. Where to watch. JustWatch.English. Alternative Titles. Heartstopper, Трепет сердца: Навсегда. Heartstopper: Forever will be the closing chapter on Nick and Charlie’s #gay love story after three seasons. Have you read the books? See first-look photos from Heartstopper Forever, starring Joe Locke and Kit Connor.Yasmin Finney as Elle and Will Gao as Tao in Heartstopper Forever.

# %%
print(search_tool.name)
print(search_tool.description)
print(search_tool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# # Build-in-Shell-tool

# %%
# !pip install langchain-experimental
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.2/211.2 kB 8.8 MB/s eta 0:00:00
# ...

# %%
from langchain_community.tools import ShellTool
shell_tool = ShellTool()
result = shell_tool.invoke('ls')
print(result)
# Out:
# Executing command:
#  ls
# sample_data

# %%
print(shell_tool.name)
print(shell_tool.description)
print(shell_tool.args)
# Out:
# terminal
# Run shell commands on this Linux machine.
# {'commands': {'anyOf': [{'type': 'string'}, {'items': {'type': 'string'}, 'type': 'array'}], 'description': 'List of shell commands to run. Deserialized using json.loads', 'title': 'Commands'}}
